# %%
# Import necessary libraries
import pandas as pd
import re
import spacy
import joblib
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from transformers import pipeline

# %%
# Load the dataset
data = pd.read_csv('IMDB_Dataset.csv')

# Data Cleaning
def clean_text(text):
    text = text.lower()
    text = re.sub(r'<br />', ' ', text)
    text = re.sub(r'[^a-z\s]', '', text)
    return text

data['review'] = data['review'].apply(clean_text)

# Convert sentiment labels to binary format
data['sentiment'] = data['sentiment'].apply(lambda x: 1 if x == 'positive' else 0)

# %%
# Splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(data['review'], data['sentiment'], test_size=0.2, random_state=42)

# Text Vectorization
tfidf = TfidfVectorizer(max_features=5000)
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf = tfidf.transform(X_test)

# %%
# Initialize the models

svm_model = SVC(kernel='linear')
# Train the models

svm_model.fit(X_train_tfidf, y_train)


# Predict on the test set
svm_predictions = svm_model.predict(X_test_tfidf)


# Evaluate the models

print("SVM Accuracy:", accuracy_score(y_test, svm_predictions))


# Classification reports
print("SVM Classification Report:\n", classification_report(y_test, svm_predictions))

# Testing SVM Model on the dataset
print("SVM Predictions:\n", svm_predictions)
print("SVM Accuracy:", accuracy_score(y_test, svm_predictions))
print("SVM Classification Report:\n", classification_report(y_test, svm_predictions))
# Out:
# SVM Accuracy: 0.8921
# SVM Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89      4961
#            1       0.89      0.90      0.89      5039
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000
#
# SVM Predictions:
#  [0 1 0 ... 1 0 1]
# SVM Accuracy: 0.8921
# SVM Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89      4961
#            1       0.89      0.90      0.89      5039
#
#     accuracy                           0.89     10000
#    macro avg       0.89      0.89      0.89     10000
# weighted avg       0.89      0.89      0.89     10000

# %%
print("\nSVM Predictions and Actual Results:")
for i, (prediction, actual) in enumerate(zip(svm_predictions, y_test)):
    print(f"Review {i+1}: Prediction={prediction}, Actual={actual}")
# Out:
# SVM Predictions and Actual Results:
# Review 1: Prediction=0, Actual=1
# Review 2: Prediction=1, Actual=1
# Review 3: Prediction=0, Actual=0
# Review 4: Prediction=1, Actual=1
# Review 5: Prediction=0, Actual=0
# Review 6: Prediction=1, Actual=1
# Review 7: Prediction=1, Actual=1
# Review 8: Prediction=0, Actual=1
# Review 9: Prediction=0, Actual=0
# Review 10: Prediction=0, Actual=0
# Review 11: Prediction=0, Actual=0
# Review 12: Prediction=1, Actual=1
# Review 13: Prediction=0, Actual=0
# Review 14: Prediction=0, Actual=0
# Review 15: Prediction=0, Actual=0
# Review 16: Prediction=1, Actual=1
# Review 17: Prediction=1, Actual=1
# Review 18: Prediction=1, Actual=1
# Review 19: Prediction=1, Actual=1
# Review 20: Prediction=1, Actual=1
# Review 21: Prediction=0, Actual=1
# Review 22: Prediction=1, Actual=1
# Review 23: Prediction=1, Actual=1
# Review 24: Prediction=0, Actual=1
# Review 25: Prediction=1, Actual=1
# Review 26: Prediction=1, Actual=1
# Review 27: Prediction=1, Actual=1
# Review 28: Prediction=1, Actual=1
# Review 29: Prediction=0, Actual=0
# Review 30: Prediction=1, Actual=1
# Review 31: Prediction=0, Actual=0
# Review 32: Prediction=1, Actual=1
# Review 33: Prediction=0, Actual=0
# Review 34: Prediction=0, Actual=0
# Review 35: Prediction=1, Actual=1
# Review 36: Prediction=0, Actual=0
# Review 37: Prediction=0, Actual=0
# Review 38: Prediction=0, Actual=0
# Review 39: Prediction=0, Actual=0
# Review 40: Prediction=0, Actual=0
# Review 41: Prediction=0, Actual=0
# Review 42: Prediction=1, Actual=1
# Review 43: Prediction=0, Actual=0
# Review 44: Prediction=0, Actual=0
# Review 45: Prediction=1, Actual=1
# Review 46: Prediction=1, Actual=1
# Review 47: Prediction=1, Actual=1
# Review 48: Prediction=1, Actual=1
# Review 49: Prediction=1, Actual=1
# Review 50: Prediction=1, Actual=1
# Review 51: Prediction=0, Actual=0
# Review 52: Prediction=1, Actual=1
# Review 53: Prediction=0, Actual=0
# Review 54: Prediction=1, Actual=1
# Review 55: Prediction=1, Actual=0
# Review 56: Prediction=1, Actual=1
# Review 57: Prediction=0, Actual=0
# Review 58: Prediction=1, Actual=1
# Review 59: Prediction=1, Actual=0
# Review 60: Prediction=0, Actual=0
# Review 61: Prediction=0, Actual=0
# Review 62: Prediction=0, Actual=0
# Review 63: Prediction=0, Actual=0
# Review 64: Prediction=1, Actual=0
# Review 65: Prediction=0, Actual=1
# Review 66: Prediction=1, Actual=1
# Review 67: Prediction=0, Actual=0
# Review 68: Prediction=0, Actual=0
# Review 69: Prediction=0, Actual=0
# Review 70: Prediction=1, Actual=0
# Review 71: Prediction=0, Actual=0
# Review 72: Prediction=0, Actual=0
# Review 73: Prediction=1, Actual=0
# Review 74: Prediction=0, Actual=0
# Review 75: Prediction=1, Actual=1
# Review 76: Prediction=1, Actual=1
# Review 77: Prediction=0, Actual=0
# Review 78: Prediction=1, Actual=1
# Review 79: Prediction=0, Actual=0
# Review 80: Prediction=0, Actual=0
# Review 81: Prediction=0, Actual=0
# Review 82: Prediction=0, Actual=0
# Review 83: Prediction=1, Actual=1
# Review 84: Prediction=1, Actual=1
# Review 85: Prediction=1, Actual=1
# Review 86: Prediction=0, Actual=0
# Review 87: Prediction=1, Actual=1
# Review 88: Prediction=1, Actual=1
# Review 89: Prediction=0, Actual=1
# Review 90: Prediction=1, Actual=1
# Review 91: Prediction=0, Actual=0
# Review 92: Prediction=0, Actual=0
# Review 93: Prediction=0, Actual=0
# Review 94: Prediction=0, Actual=0
# Review 95: Prediction=1, Actual=1
# Review 96: Prediction=1, Actual=1
# Review 97: Prediction=1, Actual=1
# Review 98: Prediction=1, Actual=1
# Review 99: Prediction=1, Actual=1
# Review 100: Prediction=1, Actual=1
# Review 101: Prediction=1, Actual=1
# Review 102: Prediction=0, Actual=0
# Review 103: Prediction=0, Actual=0
# Review 104: Prediction=1, Actual=1
# Review 105: Prediction=0, Actual=0
# Review 106: Prediction=1, Actual=1
# Review 107: Prediction=0, Actual=0
# Review 108: Prediction=0, Actual=0
# Review 109: Prediction=1, Actual=1
# Review 110: Prediction=0, Actual=0
# Review 111: Prediction=0, Actual=0
# Review 112: Prediction=0, Actual=0
# Review 113: Prediction=0, Actual=0
# Review 114: Prediction=0, Actual=0
# Review 115: Prediction=0, Actual=0
# Review 116: Prediction=0, Actual=0
# Review 117: Prediction=1, Actual=1
# Review 118: Prediction=1, Actual=1
# Review 119: Prediction=1, Actual=1
# Review 120: Prediction=1, Actual=1
# Review 121: Prediction=0, Actual=0
# Review 122: Prediction=1, Actual=1
# Review 123: Prediction=1, Actual=1
# Review 124: Prediction=1, Actual=1
# Review 125: Prediction=1, Actual=0
# Review 126: Prediction=1, Actual=1
# Review 127: Prediction=1, Actual=1
# Review 128: Prediction=0, Actual=0
# Review 129: Prediction=0, Actual=0
# Review 130: Prediction=0, Actual=0
# Review 131: Prediction=0, Actual=0
# Review 132: Prediction=1, Actual=1
# Review 133: Prediction=1, Actual=1
# Review 134: Prediction=0, Actual=0
# Review 135: Prediction=1, Actual=1
# Review 136: Prediction=1, Actual=1
# Review 137: Prediction=0, Actual=0
# Review 138: Prediction=0, Actual=0
# Review 139: Prediction=1, Actual=1
# Review 140: Prediction=1, Actual=1
# Review 141: Prediction=0, Actual=0
# Review 142: Prediction=1, Actual=1
# Review 143: Prediction=1, Actual=1
# Review 144: Prediction=1, Actual=1
# Review 145: Prediction=0, Actual=0
# Review 146: Prediction=0, Actual=1
# Review 147: Prediction=0, Actual=0
# Review 148: Prediction=1, Actual=1
# Review 149: Prediction=0, Actual=0
# Review 150: Prediction=1, Actual=1
# Review 151: Prediction=1, Actual=1
# Review 152: Prediction=0, Actual=0
# Review 153: Prediction=0, Actual=0
# Review 154: Prediction=1, Actual=1
# Review 155: Prediction=0, Actual=0
# Review 156: Prediction=1, Actual=1
# Review 157: Prediction=1, Actual=1
# Review 158: Prediction=1, Actual=0
# Review 159: Prediction=0, Actual=0
# Review 160: Prediction=0, Actual=0
# Review 161: Prediction=1, Actual=1
# Review 162: Prediction=1, Actual=1
# Review 163: Prediction=1, Actual=1
# Review 164: Prediction=0, Actual=0
# Review 165: Prediction=0, Actual=0
# Review 166: Prediction=1, Actual=1
# Review 167: Prediction=0, Actual=0
# Review 168: Prediction=0, Actual=0
# Review 169: Prediction=0, Actual=0
# Review 170: Prediction=0, Actual=0
# Review 171: Prediction=1, Actual=1
# Review 172: Prediction=1, Actual=1
# Review 173: Prediction=0, Actual=0
# Review 174: Prediction=1, Actual=1
# Review 175: Prediction=0, Actual=0
# Review 176: Prediction=1, Actual=1
# Review 177: Prediction=0, Actual=1
# Review 178: Prediction=1, Actual=1
# Review 179: Prediction=0, Actual=0
# Review 180: Prediction=0, Actual=0
# Review 181: Prediction=0, Actual=0
# Review 182: Prediction=1, Actual=1
# Review 183: Prediction=0, Actual=1
# Review 184: Prediction=0, Actual=1
# Review 185: Prediction=1, Actual=1
# Review 186: Prediction=1, Actual=1
# Review 187: Prediction=1, Actual=1
# Review 188: Prediction=0, Actual=0
# Review 189: Prediction=1, Actual=1
# Review 190: Prediction=0, Actual=0
# Review 191: Prediction=1, Actual=1
# Review 192: Prediction=1, Actual=1
# Review 193: Prediction=1, Actual=1
# Review 194: Prediction=0, Actual=0
# Review 195: Prediction=1, Actual=1
# Review 196: Prediction=0, Actual=0
# Review 197: Prediction=1, Actual=1
# Review 198: Prediction=0, Actual=0
# Review 199: Prediction=0, Actual=1
# Review 200: Prediction=0, Actual=1
# Review 201: Prediction=0, Actual=0
# Review 202: Prediction=0, Actual=0
# Review 203: Prediction=0, Actual=0
# Review 204: Prediction=1, Actual=1
# Review 205: Prediction=1, Actual=1
# Review 206: Prediction=1, Actual=1
# Review 207: Prediction=1, Actual=1
# Review 208: Prediction=1, Actual=1
# Review 209: Prediction=1, Actual=1
# Review 210: Prediction=1, Actual=1
# Review 211: Prediction=1, Actual=1
# Review 212: Prediction=1, Actual=1
# Review 213: Prediction=1, Actual=1
# Review 214: Prediction=1, Actual=0
# Review 215: Prediction=1, Actual=1
# Review 216: Prediction=1, Actual=0
# Review 217: Prediction=1, Actual=1
# Review 218: Prediction=0, Actual=0
# Review 219: Prediction=0, Actual=0
# Review 220: Prediction=0, Actual=0
# Review 221: Prediction=1, Actual=1
# Review 222: Prediction=0, Actual=0
# Review 223: Prediction=1, Actual=1
# Review 224: Prediction=0, Actual=0
# Review 225: Prediction=1, Actual=0
# Review 226: Prediction=1, Actual=1
# Review 227: Prediction=1, Actual=1
# Review 228: Prediction=1, Actual=1
# Review 229: Prediction=0, Actual=0
# Review 230: Prediction=0, Actual=0
# Review 231: Prediction=1, Actual=1
# Review 232: Prediction=1, Actual=0
# Review 233: Prediction=0, Actual=0
# Review 234: Prediction=1, Actual=1
# Review 235: Prediction=0, Actual=0
# Review 236: Prediction=0, Actual=0
# Review 237: Prediction=1, Actual=1
# Review 238: Prediction=1, Actual=1
# Review 239: Prediction=0, Actual=0
# Review 240: Prediction=0, Actual=0
# Review 241: Prediction=0, Actual=0
# Review 242: Prediction=0, Actual=0
# Review 243: Prediction=0, Actual=0
# Review 244: Prediction=0, Actual=0
# Review 245: Prediction=1, Actual=0
# Review 246: Prediction=0, Actual=0
# Review 247: Prediction=0, Actual=0
# Review 248: Prediction=1, Actual=1
# Review 249: Prediction=0, Actual=0
# Review 250: Prediction=1, Actual=1
# Review 251: Prediction=1, Actual=1
# Review 252: Prediction=1, Actual=1
# Review 253: Prediction=1, Actual=1
# Review 254: Prediction=0, Actual=0
# Review 255: Prediction=1, Actual=0
# Review 256: Prediction=0, Actual=0
# Review 257: Prediction=0, Actual=0
# Review 258: Prediction=0, Actual=0
# Review 259: Prediction=0, Actual=0
# Review 260: Prediction=1, Actual=1
# Review 261: Prediction=0, Actual=0
# Review 262: Prediction=1, Actual=1
# Review 263: Prediction=0, Actual=0
# Review 264: Prediction=0, Actual=0
# Review 265: Prediction=1, Actual=1
# Review 266: Prediction=0, Actual=0
# Review 267: Prediction=1, Actual=1
# Review 268: Prediction=1, Actual=0
# Review 269: Prediction=1, Actual=1
# Review 270: Prediction=1, Actual=1
# Review 271: Prediction=0, Actual=0
# Review 272: Prediction=1, Actual=1
# Review 273: Prediction=0, Actual=0
# Review 274: Prediction=0, Actual=0
# Review 275: Prediction=1, Actual=1
# Review 276: Prediction=0, Actual=0
# Review 277: Prediction=1, Actual=1
# Review 278: Prediction=1, Actual=1
# Review 279: Prediction=1, Actual=1
# Review 280: Prediction=1, Actual=1
# Review 281: Prediction=0, Actual=0
# Review 282: Prediction=1, Actual=1
# Review 283: Prediction=1, Actual=1
# Review 284: Prediction=1, Actual=1
# Review 285: Prediction=1, Actual=1
# Review 286: Prediction=1, Actual=1
# Review 287: Prediction=1, Actual=0
# Review 288: Prediction=1, Actual=1
# Review 289: Prediction=0, Actual=0
# Review 290: Prediction=1, Actual=1
# Review 291: Prediction=1, Actual=1
# Review 292: Prediction=1, Actual=1
# Review 293: Prediction=0, Actual=1
# Review 294: Prediction=1, Actual=1
# Review 295: Prediction=0, Actual=0
# Review 296: Prediction=0, Actual=0
# Review 297: Prediction=0, Actual=0
# Review 298: Prediction=1, Actual=1
# Review 299: Prediction=0, Actual=1
# Review 300: Prediction=0, Actual=0
# Review 301: Prediction=0, Actual=0
# Review 302: Prediction=1, Actual=1
# Review 303: Prediction=0, Actual=0
# Review 304: Prediction=0, Actual=0
# Review 305: Prediction=1, Actual=1
# Review 306: Prediction=1, Actual=1
# Review 307: Prediction=0, Actual=0
# Review 308: Prediction=0, Actual=0
# Review 309: Prediction=0, Actual=0
# Review 310: Prediction=1, Actual=0
# Review 311: Prediction=1, Actual=0
# Review 312: Prediction=0, Actual=0
# Review 313: Prediction=1, Actual=1
# Review 314: Prediction=1, Actual=1
# Review 315: Prediction=0, Actual=0
# Review 316: Prediction=1, Actual=1
# Review 317: Prediction=1, Actual=0
# Review 318: Prediction=1, Actual=1
# Review 319: Prediction=0, Actual=1
# Review 320: Prediction=0, Actual=0
# Review 321: Prediction=0, Actual=0
# Review 322: Prediction=0, Actual=0
# Review 323: Prediction=1, Actual=1
# Review 324: Prediction=0, Actual=0
# Review 325: Prediction=0, Actual=0
# Review 326: Prediction=1, Actual=1
# Review 327: Prediction=1, Actual=1
# Review 328: Prediction=1, Actual=1
# Review 329: Prediction=1, Actual=1
# Review 330: Prediction=1, Actual=1
# Review 331: Prediction=0, Actual=0
# Review 332: Prediction=0, Actual=0
# Review 333: Prediction=0, Actual=0
# Review 334: Prediction=1, Actual=1
# Review 335: Prediction=1, Actual=1
# Review 336: Prediction=1, Actual=1
# Review 337: Prediction=0, Actual=0
# Review 338: Prediction=1, Actual=1
# Review 339: Prediction=0, Actual=0
# Review 340: Prediction=0, Actual=0
# Review 341: Prediction=1, Actual=1
# Review 342: Prediction=1, Actual=1
# Review 343: Prediction=0, Actual=0
# Review 344: Prediction=0, Actual=0
# Review 345: Prediction=0, Actual=0
# Review 346: Prediction=0, Actual=0
# Review 347: Prediction=0, Actual=0
# Review 348: Prediction=0, Actual=0
# Review 349: Prediction=0, Actual=0
# Review 350: Prediction=1, Actual=1
# Review 351: Prediction=0, Actual=0
# Review 352: Prediction=1, Actual=1
# Review 353: Prediction=0, Actual=0
# Review 354: Prediction=0, Actual=0
# Review 355: Prediction=0, Actual=0
# Review 356: Prediction=1, Actual=0
# Review 357: Prediction=0, Actual=0
# Review 358: Prediction=1, Actual=1
# Review 359: Prediction=0, Actual=0
# Review 360: Prediction=0, Actual=0
# Review 361: Prediction=0, Actual=0
# Review 362: Prediction=0, Actual=0
# Review 363: Prediction=0, Actual=0
# Review 364: Prediction=0, Actual=0
# Review 365: Prediction=1, Actual=0
# Review 366: Prediction=1, Actual=1
# Review 367: Prediction=1, Actual=1
# Review 368: Prediction=0, Actual=0
# Review 369: Prediction=1, Actual=1
# Review 370: Prediction=0, Actual=0
# Review 371: Prediction=1, Actual=1
# Review 372: Prediction=1, Actual=1
# Review 373: Prediction=1, Actual=1
# Review 374: Prediction=0, Actual=0
# Review 375: Prediction=1, Actual=1
# Review 376: Prediction=1, Actual=1
# Review 377: Prediction=1, Actual=1
# Review 378: Prediction=0, Actual=0
# Review 379: Prediction=0, Actual=0
# Review 380: Prediction=0, Actual=0
# Review 381: Prediction=1, Actual=1
# Review 382: Prediction=0, Actual=0
# Review 383: Prediction=0, Actual=0
# Review 384: Prediction=0, Actual=0
# Review 385: Prediction=0, Actual=0
# Review 386: Prediction=1, Actual=1
# Review 387: Prediction=0, Actual=0
# Review 388: Prediction=1, Actual=1
# Review 389: Prediction=1, Actual=0
# Review 390: Prediction=0, Actual=0
# Review 391: Prediction=0, Actual=0
# Review 392: Prediction=0, Actual=0
# Review 393: Prediction=1, Actual=1
# Review 394: Prediction=0, Actual=0
# Review 395: Prediction=0, Actual=0
# Review 396: Prediction=1, Actual=1
# Review 397: Prediction=1, Actual=1
# Review 398: Prediction=0, Actual=0
# Review 399: Prediction=0, Actual=0
# Review 400: Prediction=1, Actual=0
# Review 401: Prediction=0, Actual=0
# Review 402: Prediction=0, Actual=0
# Review 403: Prediction=1, Actual=1
# Review 404: Prediction=1, Actual=1
# Review 405: Prediction=1, Actual=0
# Review 406: Prediction=1, Actual=1
# Review 407: Prediction=1, Actual=0
# Review 408: Prediction=1, Actual=0
# Review 409: Prediction=0, Actual=0
# Review 410: Prediction=1, Actual=1
# Review 411: Prediction=0, Actual=0
# Review 412: Prediction=0, Actual=1
# Review 413: Prediction=1, Actual=1
# Review 414: Prediction=0, Actual=0
# Review 415: Prediction=0, Actual=1
# Review 416: Prediction=0, Actual=0
# Review 417: Prediction=1, Actual=1
# Review 418: Prediction=0, Actual=0
# Review 419: Prediction=0, Actual=0
# Review 420: Prediction=1, Actual=1
# Review 421: Prediction=0, Actual=0
# Review 422: Prediction=0, Actual=0
# Review 423: Prediction=1, Actual=1
# Review 424: Prediction=1, Actual=1
# Review 425: Prediction=1, Actual=1
# Review 426: Prediction=0, Actual=0
# Review 427: Prediction=1, Actual=1
# Review 428: Prediction=0, Actual=0
# Review 429: Prediction=0, Actual=0
# Review 430: Prediction=1, Actual=1
# Review 431: Prediction=0, Actual=0
# Review 432: Prediction=0, Actual=0
# Review 433: Prediction=1, Actual=1
# Review 434: Prediction=0, Actual=0
# Review 435: Prediction=1, Actual=0
# Review 436: Prediction=1, Actual=1
# Review 437: Prediction=1, Actual=1
# Review 438: Prediction=1, Actual=1
# Review 439: Prediction=0, Actual=0
# Review 440: Prediction=1, Actual=1
# Review 441: Prediction=0, Actual=0
# Review 442: Prediction=0, Actual=0
# Review 443: Prediction=1, Actual=1
# Review 444: Prediction=1, Actual=1
# Review 445: Prediction=0, Actual=0
# Review 446: Prediction=1, Actual=1
# Review 447: Prediction=0, Actual=0
# Review 448: Prediction=1, Actual=0
# Review 449: Prediction=0, Actual=0
# Review 450: Prediction=1, Actual=0
# Review 451: Prediction=0, Actual=0
# Review 452: Prediction=0, Actual=0
# Review 453: Prediction=1, Actual=1
# Review 454: Prediction=0, Actual=0
# Review 455: Prediction=1, Actual=1
# Review 456: Prediction=1, Actual=1
# Review 457: Prediction=0, Actual=0
# Review 458: Prediction=1, Actual=1
# Review 459: Prediction=1, Actual=1
# Review 460: Prediction=1, Actual=1
# Review 461: Prediction=1, Actual=1
# Review 462: Prediction=0, Actual=0
# Review 463: Prediction=0, Actual=1
# Review 464: Prediction=1, Actual=1
# Review 465: Prediction=1, Actual=1
# Review 466: Prediction=0, Actual=0
# Review 467: Prediction=0, Actual=1
# Review 468: Prediction=0, Actual=0
# Review 469: Prediction=1, Actual=1
# Review 470: Prediction=1, Actual=1
# Review 471: Prediction=1, Actual=1
# Review 472: Prediction=1, Actual=1
# Review 473: Prediction=0, Actual=0
# Review 474: Prediction=1, Actual=0
# Review 475: Prediction=1, Actual=1
# Review 476: Prediction=0, Actual=0
# Review 477: Prediction=0, Actual=0
# Review 478: Prediction=1, Actual=1
# Review 479: Prediction=0, Actual=0
# Review 480: Prediction=1, Actual=1
# Review 481: Prediction=1, Actual=1
# Review 482: Prediction=1, Actual=1
# Review 483: Prediction=0, Actual=0
# Review 484: Prediction=0, Actual=0
# Review 485: Prediction=0, Actual=1
# Review 486: Prediction=0, Actual=0
# Review 487: Prediction=1, Actual=1
# Review 488: Prediction=1, Actual=1
# Review 489: Prediction=1, Actual=1
# Review 490: Prediction=1, Actual=1
# Review 491: Prediction=1, Actual=1
# Review 492: Prediction=0, Actual=0
# Review 493: Prediction=0, Actual=0
# Review 494: Prediction=1, Actual=1
# Review 495: Prediction=1, Actual=1
# Review 496: Prediction=0, Actual=0
# Review 497: Prediction=0, Actual=0
# Review 498: Prediction=1, Actual=1
# Review 499: Prediction=1, Actual=1
# Review 500: Prediction=1, Actual=1
# Review 501: Prediction=0, Actual=0
# Review 502: Prediction=1, Actual=1
# Review 503: Prediction=1, Actual=1
# Review 504: Prediction=1, Actual=1
# Review 505: Prediction=1, Actual=1
# Review 506: Prediction=1, Actual=0
# Review 507: Prediction=0, Actual=0
# Review 508: Prediction=1, Actual=1
# Review 509: Prediction=0, Actual=0
# Review 510: Prediction=0, Actual=0
# Review 511: Prediction=1, Actual=1
# Review 512: Prediction=0, Actual=0
# Review 513: Prediction=1, Actual=1
# Review 514: Prediction=0, Actual=0
# Review 515: Prediction=0, Actual=0
# Review 516: Prediction=0, Actual=0
# Review 517: Prediction=0, Actual=0
# Review 518: Prediction=1, Actual=1
# Review 519: Prediction=1, Actual=1
# Review 520: Prediction=0, Actual=0
# Review 521: Prediction=0, Actual=0
# Review 522: Prediction=1, Actual=1
# Review 523: Prediction=0, Actual=0
# Review 524: Prediction=1, Actual=1
# Review 525: Prediction=1, Actual=0
# Review 526: Prediction=0, Actual=0
# Review 527: Prediction=1, Actual=1
# Review 528: Prediction=1, Actual=0
# Review 529: Prediction=1, Actual=1
# Review 530: Prediction=0, Actual=0
# Review 531: Prediction=0, Actual=0
# Review 532: Prediction=0, Actual=0
# Review 533: Prediction=1, Actual=1
# Review 534: Prediction=1, Actual=0
# Review 535: Prediction=1, Actual=0
# Review 536: Prediction=1, Actual=1
# Review 537: Prediction=0, Actual=0
# Review 538: Prediction=1, Actual=1
# Review 539: Prediction=1, Actual=1
# Review 540: Prediction=1, Actual=1
# Review 541: Prediction=0, Actual=0
# Review 542: Prediction=1, Actual=1
# Review 543: Prediction=0, Actual=0
# Review 544: Prediction=1, Actual=1
# Review 545: Prediction=0, Actual=0
# Review 546: Prediction=1, Actual=1
# Review 547: Prediction=1, Actual=1
# Review 548: Prediction=0, Actual=0
# Review 549: Prediction=0, Actual=0
# Review 550: Prediction=1, Actual=1
# Review 551: Prediction=1, Actual=1
# Review 552: Prediction=1, Actual=1
# Review 553: Prediction=0, Actual=0
# Review 554: Prediction=0, Actual=0
# Review 555: Prediction=0, Actual=0
# Review 556: Prediction=1, Actual=1
# Review 557: Prediction=1, Actual=0
# Review 558: Prediction=0, Actual=0
# Review 559: Prediction=1, Actual=1
# Review 560: Prediction=1, Actual=1
# Review 561: Prediction=0, Actual=0
# Review 562: Prediction=0, Actual=0
# Review 563: Prediction=0, Actual=1
# Review 564: Prediction=0, Actual=1
# Review 565: Prediction=0, Actual=0
# Review 566: Prediction=0, Actual=0
# Review 567: Prediction=1, Actual=1
# Review 568: Prediction=1, Actual=1
# Review 569: Prediction=1, Actual=1
# Review 570: Prediction=1, Actual=1
# Review 571: Prediction=1, Actual=1
# Review 572: Prediction=1, Actual=1
# Review 573: Prediction=1, Actual=1
# Review 574: Prediction=0, Actual=0
# Review 575: Prediction=0, Actual=0
# Review 576: Prediction=1, Actual=0
# Review 577: Prediction=0, Actual=0
# Review 578: Prediction=1, Actual=1
# Review 579: Prediction=0, Actual=0
# Review 580: Prediction=0, Actual=0
# Review 581: Prediction=1, Actual=1
# Review 582: Prediction=1, Actual=0
# Review 583: Prediction=0, Actual=0
# Review 584: Prediction=0, Actual=0
# Review 585: Prediction=1, Actual=1
# Review 586: Prediction=0, Actual=0
# Review 587: Prediction=0, Actual=0
# Review 588: Prediction=1, Actual=1
# Review 589: Prediction=0, Actual=1
# Review 590: Prediction=0, Actual=0
# Review 591: Prediction=0, Actual=0
# Review 592: Prediction=0, Actual=1
# Review 593: Prediction=0, Actual=0
# Review 594: Prediction=0, Actual=0
# Review 595: Prediction=0, Actual=0
# Review 596: Prediction=1, Actual=1
# Review 597: Prediction=0, Actual=0
# Review 598: Prediction=1, Actual=1
# Review 599: Prediction=0, Actual=0
# Review 600: Prediction=0, Actual=0
# Review 601: Prediction=1, Actual=1
# Review 602: Prediction=1, Actual=1
# Review 603: Prediction=1, Actual=1
# Review 604: Prediction=1, Actual=1
# Review 605: Prediction=0, Actual=0
# Review 606: Prediction=0, Actual=1
# Review 607: Prediction=0, Actual=0
# Review 608: Prediction=0, Actual=1
# Review 609: Prediction=1, Actual=1
# Review 610: Prediction=0, Actual=0
# Review 611: Prediction=0, Actual=0
# Review 612: Prediction=1, Actual=1
# Review 613: Prediction=0, Actual=0
# Review 614: Prediction=1, Actual=1
# Review 615: Prediction=1, Actual=1
# Review 616: Prediction=1, Actual=1
# Review 617: Prediction=1, Actual=1
# Review 618: Prediction=0, Actual=0
# Review 619: Prediction=1, Actual=0
# Review 620: Prediction=0, Actual=0
# Review 621: Prediction=1, Actual=1
# Review 622: Prediction=0, Actual=0
# Review 623: Prediction=0, Actual=0
# Review 624: Prediction=1, Actual=1
# Review 625: Prediction=1, Actual=1
# Review 626: Prediction=1, Actual=1
# Review 627: Prediction=1, Actual=1
# Review 628: Prediction=0, Actual=0
# Review 629: Prediction=1, Actual=1
# Review 630: Prediction=1, Actual=1
# Review 631: Prediction=1, Actual=1
# Review 632: Prediction=0, Actual=0
# Review 633: Prediction=0, Actual=0
# Review 634: Prediction=0, Actual=0
# Review 635: Prediction=0, Actual=1
# Review 636: Prediction=0, Actual=0
# Review 637: Prediction=1, Actual=1
# Review 638: Prediction=1, Actual=1
# Review 639: Prediction=0, Actual=0
# Review 640: Prediction=1, Actual=1
# Review 641: Prediction=1, Actual=0
# Review 642: Prediction=0, Actual=0
# Review 643: Prediction=0, Actual=0
# Review 644: Prediction=0, Actual=0
# Review 645: Prediction=1, Actual=1
# Review 646: Prediction=1, Actual=1
# Review 647: Prediction=1, Actual=1
# Review 648: Prediction=0, Actual=0
# Review 649: Prediction=0, Actual=0
# Review 650: Prediction=1, Actual=0
# Review 651: Prediction=1, Actual=0
# Review 652: Prediction=0, Actual=0
# Review 653: Prediction=0, Actual=0
# Review 654: Prediction=1, Actual=0
# Review 655: Prediction=0, Actual=0
# Review 656: Prediction=1, Actual=1
# Review 657: Prediction=0, Actual=0
# Review 658: Prediction=1, Actual=1
# Review 659: Prediction=0, Actual=0
# Review 660: Prediction=1, Actual=0
# Review 661: Prediction=0, Actual=0
# Review 662: Prediction=0, Actual=0
# Review 663: Prediction=1, Actual=1
# Review 664: Prediction=1, Actual=1
# Review 665: Prediction=1, Actual=1
# Review 666: Prediction=0, Actual=0
# Review 667: Prediction=1, Actual=0
# Review 668: Prediction=0, Actual=0
# Review 669: Prediction=1, Actual=1
# Review 670: Prediction=1, Actual=1
# Review 671: Prediction=0, Actual=0
# Review 672: Prediction=0, Actual=0
# Review 673: Prediction=0, Actual=0
# Review 674: Prediction=0, Actual=1
# Review 675: Prediction=0, Actual=0
# Review 676: Prediction=0, Actual=0
# Review 677: Prediction=0, Actual=0
# Review 678: Prediction=0, Actual=0
# Review 679: Prediction=0, Actual=0
# Review 680: Prediction=1, Actual=1
# Review 681: Prediction=1, Actual=1
# Review 682: Prediction=0, Actual=1
# Review 683: Prediction=1, Actual=1
# Review 684: Prediction=1, Actual=1
# Review 685: Prediction=1, Actual=1
# Review 686: Prediction=1, Actual=1
# Review 687: Prediction=0, Actual=0
# Review 688: Prediction=0, Actual=0
# Review 689: Prediction=1, Actual=1
# Review 690: Prediction=0, Actual=0
# Review 691: Prediction=0, Actual=0
# Review 692: Prediction=1, Actual=1
# Review 693: Prediction=0, Actual=0
# Review 694: Prediction=0, Actual=0
# Review 695: Prediction=0, Actual=0
# Review 696: Prediction=0, Actual=0
# Review 697: Prediction=1, Actual=1
# Review 698: Prediction=0, Actual=1
# Review 699: Prediction=1, Actual=1
# Review 700: Prediction=1, Actual=0
# Review 701: Prediction=0, Actual=0
# Review 702: Prediction=1, Actual=1
# Review 703: Prediction=0, Actual=0
# Review 704: Prediction=0, Actual=0
# Review 705: Prediction=1, Actual=0
# Review 706: Prediction=1, Actual=1
# Review 707: Prediction=1, Actual=1
# Review 708: Prediction=1, Actual=0
# Review 709: Prediction=1, Actual=0
# Review 710: Prediction=1, Actual=1
# Review 711: Prediction=0, Actual=0
# Review 712: Prediction=1, Actual=1
# Review 713: Prediction=1, Actual=1
# Review 714: Prediction=0, Actual=0
# Review 715: Prediction=0, Actual=0
# Review 716: Prediction=1, Actual=1
# Review 717: Prediction=0, Actual=0
# Review 718: Prediction=1, Actual=1
# Review 719: Prediction=0, Actual=0
# Review 720: Prediction=0, Actual=0
# Review 721: Prediction=0, Actual=0
# Review 722: Prediction=0, Actual=1
# Review 723: Prediction=1, Actual=1
# Review 724: Prediction=1, Actual=1
# Review 725: Prediction=0, Actual=0
# Review 726: Prediction=1, Actual=1
# Review 727: Prediction=1, Actual=1
# Review 728: Prediction=1, Actual=0
# Review 729: Prediction=0, Actual=1
# Review 730: Prediction=0, Actual=0
# Review 731: Prediction=1, Actual=1
# Review 732: Prediction=1, Actual=1
# Review 733: Prediction=0, Actual=0
# Review 734: Prediction=0, Actual=0
# Review 735: Prediction=1, Actual=1
# Review 736: Prediction=0, Actual=0
# Review 737: Prediction=1, Actual=1
# Review 738: Prediction=1, Actual=1
# Review 739: Prediction=1, Actual=1
# Review 740: Prediction=0, Actual=0
# Review 741: Prediction=1, Actual=1
# Review 742: Prediction=1, Actual=0
# Review 743: Prediction=1, Actual=1
# Review 744: Prediction=1, Actual=1
# Review 745: Prediction=1, Actual=1
# Review 746: Prediction=0, Actual=0
# Review 747: Prediction=1, Actual=1
# Review 748: Prediction=0, Actual=0
# Review 749: Prediction=1, Actual=1
# Review 750: Prediction=0, Actual=0
# Review 751: Prediction=1, Actual=1
# Review 752: Prediction=0, Actual=0
# Review 753: Prediction=0, Actual=0
# Review 754: Prediction=0, Actual=0
# Review 755: Prediction=0, Actual=1
# Review 756: Prediction=1, Actual=1
# Review 757: Prediction=0, Actual=0
# Review 758: Prediction=0, Actual=0
# Review 759: Prediction=0, Actual=0
# Review 760: Prediction=0, Actual=0
# Review 761: Prediction=0, Actual=0
# Review 762: Prediction=1, Actual=1
# Review 763: Prediction=0, Actual=1
# Review 764: Prediction=0, Actual=0
# Review 765: Prediction=0, Actual=0
# Review 766: Prediction=1, Actual=1
# Review 767: Prediction=0, Actual=0
# Review 768: Prediction=0, Actual=0
# Review 769: Prediction=0, Actual=0
# Review 770: Prediction=0, Actual=0
# Review 771: Prediction=1, Actual=1
# Review 772: Prediction=0, Actual=0
# Review 773: Prediction=1, Actual=1
# Review 774: Prediction=1, Actual=1
# Review 775: Prediction=0, Actual=0
# Review 776: Prediction=0, Actual=0
# Review 777: Prediction=1, Actual=0
# Review 778: Prediction=1, Actual=1
# Review 779: Prediction=1, Actual=1
# Review 780: Prediction=1, Actual=1
# Review 781: Prediction=0, Actual=0
# Review 782: Prediction=1, Actual=1
# Review 783: Prediction=1, Actual=0
# Review 784: Prediction=0, Actual=0
# Review 785: Prediction=0, Actual=0
# Review 786: Prediction=0, Actual=0
# Review 787: Prediction=1, Actual=1
# Review 788: Prediction=1, Actual=1
# Review 789: Prediction=0, Actual=0
# Review 790: Prediction=0, Actual=0
# Review 791: Prediction=1, Actual=1
# Review 792: Prediction=1, Actual=1
# Review 793: Prediction=1, Actual=1
# Review 794: Prediction=1, Actual=1
# Review 795: Prediction=0, Actual=0
# Review 796: Prediction=1, Actual=1
# Review 797: Prediction=0, Actual=0
# Review 798: Prediction=1, Actual=1
# Review 799: Prediction=0, Actual=0
# Review 800: Prediction=1, Actual=1
# Review 801: Prediction=1, Actual=1
# Review 802: Prediction=0, Actual=0
# Review 803: Prediction=0, Actual=0
# Review 804: Prediction=1, Actual=1
# Review 805: Prediction=0, Actual=0
# Review 806: Prediction=0, Actual=0
# Review 807: Prediction=0, Actual=0
# Review 808: Prediction=1, Actual=1
# Review 809: Prediction=0, Actual=0
# Review 810: Prediction=0, Actual=0
# Review 811: Prediction=0, Actual=0
# Review 812: Prediction=1, Actual=1
# Review 813: Prediction=0, Actual=0
# Review 814: Prediction=0, Actual=0
# Review 815: Prediction=1, Actual=1
# Review 816: Prediction=0, Actual=0
# Review 817: Prediction=1, Actual=1
# Review 818: Prediction=0, Actual=0
# Review 819: Prediction=0, Actual=0
# Review 820: Prediction=1, Actual=1
# Review 821: Prediction=1, Actual=0
# Review 822: Prediction=0, Actual=0
# Review 823: Prediction=0, Actual=0
# Review 824: Prediction=1, Actual=1
# Review 825: Prediction=1, Actual=1
# Review 826: Prediction=1, Actual=0
# Review 827: Prediction=1, Actual=1
# Review 828: Prediction=1, Actual=1
# Review 829: Prediction=0, Actual=0
# Review 830: Prediction=0, Actual=0
# Review 831: Prediction=0, Actual=0
# Review 832: Prediction=1, Actual=0
# Review 833: Prediction=0, Actual=1
# Review 834: Prediction=1, Actual=1
# Review 835: Prediction=1, Actual=1
# Review 836: Prediction=0, Actual=0
# Review 837: Prediction=0, Actual=0
# Review 838: Prediction=0, Actual=0
# Review 839: Prediction=1, Actual=1
# Review 840: Prediction=0, Actual=0
# Review 841: Prediction=0, Actual=0
# Review 842: Prediction=0, Actual=0
# Review 843: Prediction=0, Actual=0
# Review 844: Prediction=1, Actual=1
# Review 845: Prediction=0, Actual=0
# Review 846: Prediction=1, Actual=1
# Review 847: Prediction=1, Actual=1
# Review 848: Prediction=1, Actual=1
# Review 849: Prediction=1, Actual=1
# Review 850: Prediction=0, Actual=1
# Review 851: Prediction=0, Actual=0
# Review 852: Prediction=0, Actual=0
# Review 853: Prediction=1, Actual=1
# Review 854: Prediction=0, Actual=0
# Review 855: Prediction=0, Actual=0
# Review 856: Prediction=0, Actual=0
# Review 857: Prediction=1, Actual=0
# Review 858: Prediction=1, Actual=1
# Review 859: Prediction=1, Actual=1
# Review 860: Prediction=0, Actual=0
# Review 861: Prediction=1, Actual=1
# Review 862: Prediction=0, Actual=1
# Review 863: Prediction=0, Actual=0
# Review 864: Prediction=0, Actual=0
# Review 865: Prediction=0, Actual=0
# Review 866: Prediction=0, Actual=0
# Review 867: Prediction=0, Actual=0
# Review 868: Prediction=0, Actual=0
# Review 869: Prediction=0, Actual=0
# Review 870: Prediction=1, Actual=1
# Review 871: Prediction=1, Actual=1
# Review 872: Prediction=1, Actual=1
# Review 873: Prediction=1, Actual=1
# Review 874: Prediction=1, Actual=1
# Review 875: Prediction=1, Actual=1
# Review 876: Prediction=1, Actual=1
# Review 877: Prediction=0, Actual=0
# Review 878: Prediction=1, Actual=1
# Review 879: Prediction=0, Actual=0
# Review 880: Prediction=1, Actual=1
# Review 881: Prediction=1, Actual=1
# Review 882: Prediction=0, Actual=0
# Review 883: Prediction=0, Actual=0
# Review 884: Prediction=1, Actual=1
# Review 885: Prediction=1, Actual=1
# Review 886: Prediction=0, Actual=0
# Review 887: Prediction=0, Actual=0
# Review 888: Prediction=0, Actual=0
# Review 889: Prediction=0, Actual=0
# Review 890: Prediction=0, Actual=0
# Review 891: Prediction=1, Actual=1
# Review 892: Prediction=0, Actual=1
# Review 893: Prediction=0, Actual=0
# Review 894: Prediction=0, Actual=0
# Review 895: Prediction=1, Actual=1
# Review 896: Prediction=1, Actual=1
# Review 897: Prediction=1, Actual=1
# Review 898: Prediction=0, Actual=0
# Review 899: Prediction=1, Actual=1
# Review 900: Prediction=0, Actual=0
# Review 901: Prediction=0, Actual=0
# Review 902: Prediction=1, Actual=1
# Review 903: Prediction=1, Actual=0
# Review 904: Prediction=1, Actual=1
# Review 905: Prediction=1, Actual=1
# Review 906: Prediction=1, Actual=1
# Review 907: Prediction=1, Actual=1
# Review 908: Prediction=0, Actual=0
# Review 909: Prediction=1, Actual=1
# Review 910: Prediction=0, Actual=0
# Review 911: Prediction=0, Actual=0
# Review 912: Prediction=0, Actual=0
# Review 913: Prediction=0, Actual=0
# Review 914: Prediction=1, Actual=1
# Review 915: Prediction=1, Actual=1
# Review 916: Prediction=1, Actual=1
# Review 917: Prediction=1, Actual=1
# Review 918: Prediction=0, Actual=0
# Review 919: Prediction=1, Actual=1
# Review 920: Prediction=0, Actual=0
# Review 921: Prediction=0, Actual=0
# Review 922: Prediction=1, Actual=1
# Review 923: Prediction=0, Actual=1
# Review 924: Prediction=1, Actual=1
# Review 925: Prediction=0, Actual=0
# Review 926: Prediction=1, Actual=1
# Review 927: Prediction=1, Actual=1
# Review 928: Prediction=0, Actual=0
# Review 929: Prediction=1, Actual=1
# Review 930: Prediction=0, Actual=0
# Review 931: Prediction=1, Actual=1
# Review 932: Prediction=0, Actual=1
# Review 933: Prediction=0, Actual=0
# Review 934: Prediction=1, Actual=1
# Review 935: Prediction=0, Actual=0
# Review 936: Prediction=1, Actual=1
# Review 937: Prediction=0, Actual=0
# Review 938: Prediction=1, Actual=1
# Review 939: Prediction=0, Actual=0
# Review 940: Prediction=0, Actual=0
# Review 941: Prediction=1, Actual=1
# Review 942: Prediction=1, Actual=1
# Review 943: Prediction=0, Actual=0
# Review 944: Prediction=1, Actual=0
# Review 945: Prediction=0, Actual=0
# Review 946: Prediction=0, Actual=0
# Review 947: Prediction=0, Actual=1
# Review 948: Prediction=0, Actual=0
# Review 949: Prediction=1, Actual=1
# Review 950: Prediction=0, Actual=0
# Review 951: Prediction=0, Actual=0
# Review 952: Prediction=0, Actual=0
# Review 953: Prediction=1, Actual=1
# Review 954: Prediction=1, Actual=0
# Review 955: Prediction=0, Actual=0
# Review 956: Prediction=1, Actual=1
# Review 957: Prediction=0, Actual=0
# Review 958: Prediction=0, Actual=0
# Review 959: Prediction=1, Actual=1
# Review 960: Prediction=0, Actual=0
# Review 961: Prediction=1, Actual=0
# Review 962: Prediction=0, Actual=0
# Review 963: Prediction=1, Actual=1
# Review 964: Prediction=1, Actual=1
# Review 965: Prediction=1, Actual=1
# Review 966: Prediction=0, Actual=0
# Review 967: Prediction=0, Actual=1
# Review 968: Prediction=1, Actual=0
# Review 969: Prediction=0, Actual=0
# Review 970: Prediction=0, Actual=0
# Review 971: Prediction=0, Actual=0
# Review 972: Prediction=1, Actual=1
# Review 973: Prediction=0, Actual=0
# Review 974: Prediction=1, Actual=1
# Review 975: Prediction=0, Actual=0
# Review 976: Prediction=0, Actual=0
# Review 977: Prediction=1, Actual=0
# Review 978: Prediction=0, Actual=0
# Review 979: Prediction=1, Actual=1
# Review 980: Prediction=0, Actual=1
# Review 981: Prediction=1, Actual=1
# Review 982: Prediction=0, Actual=0
# Review 983: Prediction=0, Actual=0
# Review 984: Prediction=1, Actual=0
# Review 985: Prediction=0, Actual=0
# Review 986: Prediction=1, Actual=1
# Review 987: Prediction=1, Actual=1
# Review 988: Prediction=0, Actual=0
# Review 989: Prediction=1, Actual=1
# Review 990: Prediction=0, Actual=1
# Review 991: Prediction=0, Actual=0
# Review 992: Prediction=1, Actual=1
# Review 993: Prediction=0, Actual=0
# Review 994: Prediction=0, Actual=0
# Review 995: Prediction=0, Actual=0
# Review 996: Prediction=0, Actual=0
# Review 997: Prediction=0, Actual=0
# Review 998: Prediction=1, Actual=1
# Review 999: Prediction=1, Actual=1
# Review 1000: Prediction=0, Actual=0
# Review 1001: Prediction=1, Actual=1
# Review 1002: Prediction=1, Actual=1
# Review 1003: Prediction=0, Actual=0
# Review 1004: Prediction=0, Actual=0
# Review 1005: Prediction=1, Actual=1
# Review 1006: Prediction=1, Actual=1
# Review 1007: Prediction=1, Actual=1
# Review 1008: Prediction=0, Actual=0
# Review 1009: Prediction=1, Actual=1
# Review 1010: Prediction=1, Actual=1
# Review 1011: Prediction=1, Actual=1
# Review 1012: Prediction=0, Actual=0
# Review 1013: Prediction=1, Actual=1
# Review 1014: Prediction=0, Actual=0
# Review 1015: Prediction=0, Actual=0
# Review 1016: Prediction=1, Actual=1
# Review 1017: Prediction=0, Actual=0
# Review 1018: Prediction=0, Actual=0
# Review 1019: Prediction=0, Actual=0
# Review 1020: Prediction=1, Actual=1
# Review 1021: Prediction=0, Actual=0
# Review 1022: Prediction=0, Actual=0
# Review 1023: Prediction=0, Actual=0
# Review 1024: Prediction=1, Actual=1
# Review 1025: Prediction=0, Actual=0
# Review 1026: Prediction=0, Actual=0
# Review 1027: Prediction=0, Actual=0
# Review 1028: Prediction=1, Actual=1
# Review 1029: Prediction=0, Actual=0
# Review 1030: Prediction=1, Actual=1
# Review 1031: Prediction=1, Actual=1
# Review 1032: Prediction=0, Actual=0
# Review 1033: Prediction=1, Actual=1
# Review 1034: Prediction=1, Actual=1
# Review 1035: Prediction=1, Actual=1
# Review 1036: Prediction=0, Actual=0
# Review 1037: Prediction=1, Actual=1
# Review 1038: Prediction=1, Actual=0
# Review 1039: Prediction=1, Actual=0
# Review 1040: Prediction=0, Actual=0
# Review 1041: Prediction=0, Actual=0
# Review 1042: Prediction=0, Actual=0
# Review 1043: Prediction=0, Actual=0
# Review 1044: Prediction=0, Actual=1
# Review 1045: Prediction=0, Actual=0
# Review 1046: Prediction=0, Actual=0
# Review 1047: Prediction=0, Actual=0
# Review 1048: Prediction=1, Actual=1
# Review 1049: Prediction=0, Actual=0
# Review 1050: Prediction=1, Actual=1
# Review 1051: Prediction=0, Actual=0
# Review 1052: Prediction=0, Actual=0
# Review 1053: Prediction=0, Actual=1
# Review 1054: Prediction=0, Actual=0
# Review 1055: Prediction=1, Actual=1
# Review 1056: Prediction=0, Actual=0
# Review 1057: Prediction=0, Actual=0
# Review 1058: Prediction=0, Actual=0
# Review 1059: Prediction=0, Actual=0
# Review 1060: Prediction=1, Actual=1
# Review 1061: Prediction=0, Actual=0
# Review 1062: Prediction=1, Actual=1
# Review 1063: Prediction=1, Actual=0
# Review 1064: Prediction=1, Actual=0
# Review 1065: Prediction=1, Actual=1
# Review 1066: Prediction=1, Actual=0
# Review 1067: Prediction=1, Actual=1
# Review 1068: Prediction=0, Actual=0
# Review 1069: Prediction=1, Actual=1
# Review 1070: Prediction=1, Actual=1
# Review 1071: Prediction=1, Actual=1
# Review 1072: Prediction=0, Actual=0
# Review 1073: Prediction=0, Actual=0
# Review 1074: Prediction=0, Actual=0
# Review 1075: Prediction=1, Actual=1
# Review 1076: Prediction=1, Actual=1
# Review 1077: Prediction=1, Actual=0
# Review 1078: Prediction=0, Actual=0
# Review 1079: Prediction=0, Actual=0
# Review 1080: Prediction=1, Actual=1
# Review 1081: Prediction=1, Actual=1
# Review 1082: Prediction=0, Actual=0
# Review 1083: Prediction=1, Actual=0
# Review 1084: Prediction=0, Actual=0
# Review 1085: Prediction=1, Actual=1
# Review 1086: Prediction=0, Actual=0
# Review 1087: Prediction=0, Actual=0
# Review 1088: Prediction=0, Actual=0
# Review 1089: Prediction=0, Actual=0
# Review 1090: Prediction=0, Actual=1
# Review 1091: Prediction=1, Actual=0
# Review 1092: Prediction=1, Actual=1
# Review 1093: Prediction=1, Actual=1
# Review 1094: Prediction=0, Actual=0
# Review 1095: Prediction=1, Actual=1
# Review 1096: Prediction=0, Actual=0
# Review 1097: Prediction=0, Actual=1
# Review 1098: Prediction=1, Actual=1
# Review 1099: Prediction=1, Actual=1
# Review 1100: Prediction=0, Actual=0
# Review 1101: Prediction=1, Actual=1
# Review 1102: Prediction=0, Actual=0
# Review 1103: Prediction=1, Actual=1
# Review 1104: Prediction=0, Actual=0
# Review 1105: Prediction=1, Actual=1
# Review 1106: Prediction=0, Actual=1
# Review 1107: Prediction=1, Actual=1
# Review 1108: Prediction=0, Actual=0
# Review 1109: Prediction=0, Actual=0
# Review 1110: Prediction=1, Actual=1
# Review 1111: Prediction=1, Actual=0
# Review 1112: Prediction=1, Actual=1
# Review 1113: Prediction=1, Actual=1
# Review 1114: Prediction=0, Actual=0
# Review 1115: Prediction=1, Actual=1
# Review 1116: Prediction=0, Actual=0
# Review 1117: Prediction=0, Actual=0
# Review 1118: Prediction=0, Actual=0
# Review 1119: Prediction=0, Actual=0
# Review 1120: Prediction=0, Actual=0
# Review 1121: Prediction=0, Actual=0
# Review 1122: Prediction=0, Actual=1
# Review 1123: Prediction=1, Actual=1
# Review 1124: Prediction=1, Actual=0
# Review 1125: Prediction=0, Actual=1
# Review 1126: Prediction=1, Actual=1
# Review 1127: Prediction=1, Actual=1
# Review 1128: Prediction=1, Actual=1
# Review 1129: Prediction=1, Actual=1
# Review 1130: Prediction=0, Actual=0
# Review 1131: Prediction=0, Actual=0
# Review 1132: Prediction=1, Actual=1
# Review 1133: Prediction=1, Actual=1
# Review 1134: Prediction=1, Actual=0
# Review 1135: Prediction=0, Actual=0
# Review 1136: Prediction=0, Actual=0
# Review 1137: Prediction=1, Actual=1
# Review 1138: Prediction=0, Actual=0
# Review 1139: Prediction=0, Actual=0
# Review 1140: Prediction=0, Actual=0
# Review 1141: Prediction=0, Actual=0
# Review 1142: Prediction=1, Actual=1
# Review 1143: Prediction=1, Actual=1
# Review 1144: Prediction=1, Actual=1
# Review 1145: Prediction=1, Actual=0
# Review 1146: Prediction=1, Actual=1
# Review 1147: Prediction=0, Actual=0
# Review 1148: Prediction=1, Actual=1
# Review 1149: Prediction=0, Actual=0
# Review 1150: Prediction=1, Actual=1
# Review 1151: Prediction=1, Actual=1
# Review 1152: Prediction=1, Actual=1
# Review 1153: Prediction=0, Actual=0
# Review 1154: Prediction=1, Actual=1
# Review 1155: Prediction=1, Actual=1
# Review 1156: Prediction=0, Actual=0
# Review 1157: Prediction=1, Actual=1
# Review 1158: Prediction=0, Actual=0
# Review 1159: Prediction=1, Actual=1
# Review 1160: Prediction=0, Actual=0
# Review 1161: Prediction=0, Actual=0
# Review 1162: Prediction=1, Actual=1
# Review 1163: Prediction=0, Actual=0
# Review 1164: Prediction=1, Actual=1
# Review 1165: Prediction=0, Actual=0
# Review 1166: Prediction=1, Actual=1
# Review 1167: Prediction=0, Actual=0
# Review 1168: Prediction=1, Actual=0
# Review 1169: Prediction=1, Actual=1
# Review 1170: Prediction=1, Actual=1
# Review 1171: Prediction=1, Actual=1
# Review 1172: Prediction=1, Actual=1
# Review 1173: Prediction=0, Actual=0
# Review 1174: Prediction=1, Actual=0
# Review 1175: Prediction=1, Actual=1
# Review 1176: Prediction=0, Actual=0
# Review 1177: Prediction=1, Actual=1
# Review 1178: Prediction=0, Actual=0
# Review 1179: Prediction=1, Actual=1
# Review 1180: Prediction=1, Actual=1
# Review 1181: Prediction=1, Actual=1
# Review 1182: Prediction=0, Actual=0
# Review 1183: Prediction=1, Actual=0
# Review 1184: Prediction=1, Actual=0
# Review 1185: Prediction=0, Actual=0
# Review 1186: Prediction=1, Actual=1
# Review 1187: Prediction=0, Actual=1
# Review 1188: Prediction=1, Actual=1
# Review 1189: Prediction=1, Actual=1
# Review 1190: Prediction=1, Actual=1
# Review 1191: Prediction=1, Actual=1
# Review 1192: Prediction=1, Actual=1
# Review 1193: Prediction=0, Actual=0
# Review 1194: Prediction=0, Actual=0
# Review 1195: Prediction=1, Actual=1
# Review 1196: Prediction=1, Actual=1
# Review 1197: Prediction=1, Actual=1
# Review 1198: Prediction=0, Actual=0
# Review 1199: Prediction=0, Actual=0
# Review 1200: Prediction=0, Actual=0
# Review 1201: Prediction=1, Actual=1
# Review 1202: Prediction=1, Actual=1
# Review 1203: Prediction=1, Actual=1
# Review 1204: Prediction=0, Actual=0
# Review 1205: Prediction=0, Actual=0
# Review 1206: Prediction=0, Actual=0
# Review 1207: Prediction=0, Actual=0
# Review 1208: Prediction=1, Actual=1
# Review 1209: Prediction=1, Actual=1
# Review 1210: Prediction=1, Actual=1
# Review 1211: Prediction=1, Actual=0
# Review 1212: Prediction=1, Actual=1
# Review 1213: Prediction=1, Actual=1
# Review 1214: Prediction=1, Actual=1
# Review 1215: Prediction=1, Actual=1
# Review 1216: Prediction=0, Actual=0
# Review 1217: Prediction=0, Actual=0
# Review 1218: Prediction=1, Actual=1
# Review 1219: Prediction=0, Actual=0
# Review 1220: Prediction=0, Actual=0
# Review 1221: Prediction=0, Actual=0
# Review 1222: Prediction=1, Actual=1
# Review 1223: Prediction=1, Actual=1
# Review 1224: Prediction=1, Actual=1
# Review 1225: Prediction=1, Actual=1
# Review 1226: Prediction=0, Actual=0
# Review 1227: Prediction=1, Actual=1
# Review 1228: Prediction=1, Actual=1
# Review 1229: Prediction=1, Actual=1
# Review 1230: Prediction=0, Actual=0
# Review 1231: Prediction=1, Actual=0
# Review 1232: Prediction=1, Actual=0
# Review 1233: Prediction=0, Actual=0
# Review 1234: Prediction=0, Actual=0
# Review 1235: Prediction=0, Actual=0
# Review 1236: Prediction=0, Actual=0
# Review 1237: Prediction=0, Actual=0
# Review 1238: Prediction=0, Actual=0
# Review 1239: Prediction=0, Actual=0
# Review 1240: Prediction=0, Actual=0
# Review 1241: Prediction=0, Actual=0
# Review 1242: Prediction=1, Actual=0
# Review 1243: Prediction=1, Actual=1
# Review 1244: Prediction=0, Actual=0
# Review 1245: Prediction=1, Actual=1
# Review 1246: Prediction=1, Actual=0
# Review 1247: Prediction=0, Actual=0
# Review 1248: Prediction=0, Actual=0
# Review 1249: Prediction=0, Actual=0
# Review 1250: Prediction=1, Actual=1
# Review 1251: Prediction=1, Actual=1
# Review 1252: Prediction=1, Actual=1
# Review 1253: Prediction=1, Actual=1
# Review 1254: Prediction=0, Actual=0
# Review 1255: Prediction=1, Actual=1
# Review 1256: Prediction=0, Actual=0
# Review 1257: Prediction=1, Actual=1
# Review 1258: Prediction=0, Actual=0
# Review 1259: Prediction=1, Actual=1
# Review 1260: Prediction=0, Actual=0
# Review 1261: Prediction=0, Actual=0
# Review 1262: Prediction=0, Actual=0
# Review 1263: Prediction=1, Actual=1
# Review 1264: Prediction=1, Actual=1
# Review 1265: Prediction=0, Actual=0
# Review 1266: Prediction=0, Actual=0
# Review 1267: Prediction=0, Actual=0
# Review 1268: Prediction=1, Actual=0
# Review 1269: Prediction=0, Actual=0
# Review 1270: Prediction=1, Actual=1
# Review 1271: Prediction=1, Actual=1
# Review 1272: Prediction=0, Actual=0
# Review 1273: Prediction=1, Actual=1
# Review 1274: Prediction=1, Actual=1
# Review 1275: Prediction=1, Actual=1
# Review 1276: Prediction=1, Actual=1
# Review 1277: Prediction=1, Actual=0
# Review 1278: Prediction=1, Actual=1
# Review 1279: Prediction=1, Actual=1
# Review 1280: Prediction=0, Actual=0
# Review 1281: Prediction=1, Actual=1
# Review 1282: Prediction=1, Actual=1
# Review 1283: Prediction=1, Actual=1
# Review 1284: Prediction=0, Actual=0
# Review 1285: Prediction=1, Actual=1
# Review 1286: Prediction=1, Actual=1
# Review 1287: Prediction=1, Actual=1
# Review 1288: Prediction=1, Actual=0
# Review 1289: Prediction=1, Actual=1
# Review 1290: Prediction=1, Actual=1
# Review 1291: Prediction=0, Actual=0
# Review 1292: Prediction=0, Actual=0
# Review 1293: Prediction=1, Actual=1
# Review 1294: Prediction=1, Actual=1
# Review 1295: Prediction=0, Actual=0
# Review 1296: Prediction=1, Actual=1
# Review 1297: Prediction=0, Actual=0
# Review 1298: Prediction=1, Actual=1
# Review 1299: Prediction=1, Actual=1
# Review 1300: Prediction=0, Actual=0
# Review 1301: Prediction=1, Actual=1
# Review 1302: Prediction=1, Actual=1
# Review 1303: Prediction=1, Actual=1
# Review 1304: Prediction=0, Actual=0
# Review 1305: Prediction=1, Actual=0
# Review 1306: Prediction=1, Actual=1
# Review 1307: Prediction=1, Actual=1
# Review 1308: Prediction=0, Actual=0
# Review 1309: Prediction=1, Actual=0
# Review 1310: Prediction=1, Actual=1
# Review 1311: Prediction=1, Actual=1
# Review 1312: Prediction=1, Actual=1
# Review 1313: Prediction=0, Actual=1
# Review 1314: Prediction=0, Actual=0
# Review 1315: Prediction=0, Actual=1
# Review 1316: Prediction=1, Actual=1
# Review 1317: Prediction=1, Actual=1
# Review 1318: Prediction=1, Actual=1
# Review 1319: Prediction=0, Actual=0
# Review 1320: Prediction=0, Actual=1
# Review 1321: Prediction=1, Actual=1
# Review 1322: Prediction=1, Actual=1
# Review 1323: Prediction=0, Actual=0
# Review 1324: Prediction=1, Actual=1
# Review 1325: Prediction=0, Actual=1
# Review 1326: Prediction=1, Actual=0
# Review 1327: Prediction=1, Actual=1
# Review 1328: Prediction=1, Actual=1
# Review 1329: Prediction=0, Actual=0
# Review 1330: Prediction=1, Actual=1
# Review 1331: Prediction=0, Actual=0
# Review 1332: Prediction=1, Actual=1
# Review 1333: Prediction=0, Actual=1
# Review 1334: Prediction=0, Actual=0
# Review 1335: Prediction=1, Actual=1
# Review 1336: Prediction=1, Actual=1
# Review 1337: Prediction=1, Actual=1
# Review 1338: Prediction=1, Actual=1
# Review 1339: Prediction=0, Actual=0
# Review 1340: Prediction=0, Actual=0
# Review 1341: Prediction=0, Actual=0
# Review 1342: Prediction=0, Actual=0
# Review 1343: Prediction=1, Actual=1
# Review 1344: Prediction=1, Actual=1
# Review 1345: Prediction=0, Actual=0
# Review 1346: Prediction=1, Actual=1
# Review 1347: Prediction=1, Actual=1
# Review 1348: Prediction=1, Actual=1
# Review 1349: Prediction=0, Actual=0
# Review 1350: Prediction=1, Actual=1
# Review 1351: Prediction=0, Actual=0
# Review 1352: Prediction=1, Actual=1
# Review 1353: Prediction=0, Actual=0
# Review 1354: Prediction=0, Actual=0
# Review 1355: Prediction=1, Actual=1
# Review 1356: Prediction=1, Actual=1
# Review 1357: Prediction=1, Actual=1
# Review 1358: Prediction=1, Actual=1
# Review 1359: Prediction=1, Actual=1
# Review 1360: Prediction=0, Actual=0
# Review 1361: Prediction=1, Actual=1
# Review 1362: Prediction=1, Actual=1
# Review 1363: Prediction=1, Actual=1
# ...
# Review 9557: Prediction=1, Actual=1
# Review 9558: Prediction=1, Actual=1
# Review 9559: Prediction=0, Actual=0
# Review 9560: Prediction=0, Actual=0
# Review 9561: Prediction=1, Actual=1
# Review 9562: Prediction=0, Actual=0
# Review 9563: Prediction=1, Actual=1
# Review 9564: Prediction=1, Actual=1
# Review 9565: Prediction=1, Actual=1
# Review 9566: Prediction=1, Actual=1
# Review 9567: Prediction=1, Actual=0
# Review 9568: Prediction=0, Actual=0
# Review 9569: Prediction=1, Actual=0
# Review 9570: Prediction=1, Actual=1
# Review 9571: Prediction=0, Actual=0
# Review 9572: Prediction=1, Actual=1
# Review 9573: Prediction=1, Actual=0
# Review 9574: Prediction=0, Actual=0
# Review 9575: Prediction=0, Actual=0
# Review 9576: Prediction=0, Actual=0
# Review 9577: Prediction=1, Actual=1
# Review 9578: Prediction=1, Actual=0
# Review 9579: Prediction=0, Actual=1
# Review 9580: Prediction=1, Actual=0
# Review 9581: Prediction=0, Actual=0
# Review 9582: Prediction=1, Actual=1
# Review 9583: Prediction=1, Actual=1
# Review 9584: Prediction=0, Actual=0
# Review 9585: Prediction=0, Actual=0
# Review 9586: Prediction=0, Actual=0
# Review 9587: Prediction=0, Actual=1
# Review 9588: Prediction=0, Actual=0
# Review 9589: Prediction=1, Actual=1
# Review 9590: Prediction=1, Actual=1
# Review 9591: Prediction=1, Actual=1
# Review 9592: Prediction=1, Actual=1
# Review 9593: Prediction=0, Actual=0
# Review 9594: Prediction=0, Actual=1
# Review 9595: Prediction=1, Actual=1
# Review 9596: Prediction=1, Actual=1
# Review 9597: Prediction=0, Actual=0
# Review 9598: Prediction=0, Actual=0
# Review 9599: Prediction=1, Actual=1
# Review 9600: Prediction=1, Actual=1
# Review 9601: Prediction=0, Actual=0
# Review 9602: Prediction=1, Actual=0
# Review 9603: Prediction=0, Actual=0
# Review 9604: Prediction=1, Actual=1
# Review 9605: Prediction=1, Actual=1
# Review 9606: Prediction=1, Actual=1
# Review 9607: Prediction=0, Actual=0
# Review 9608: Prediction=0, Actual=0
# Review 9609: Prediction=1, Actual=0
# Review 9610: Prediction=0, Actual=0
# Review 9611: Prediction=1, Actual=1
# Review 9612: Prediction=1, Actual=0
# Review 9613: Prediction=0, Actual=0
# Review 9614: Prediction=1, Actual=1
# Review 9615: Prediction=0, Actual=0
# Review 9616: Prediction=0, Actual=0
# Review 9617: Prediction=1, Actual=0
# Review 9618: Prediction=1, Actual=1
# Review 9619: Prediction=1, Actual=1
# Review 9620: Prediction=0, Actual=0
# Review 9621: Prediction=0, Actual=0
# Review 9622: Prediction=0, Actual=0
# Review 9623: Prediction=0, Actual=0
# Review 9624: Prediction=1, Actual=1
# Review 9625: Prediction=0, Actual=0
# Review 9626: Prediction=0, Actual=0
# Review 9627: Prediction=1, Actual=1
# Review 9628: Prediction=0, Actual=0
# Review 9629: Prediction=0, Actual=0
# Review 9630: Prediction=1, Actual=1
# Review 9631: Prediction=1, Actual=1
# Review 9632: Prediction=1, Actual=1
# Review 9633: Prediction=0, Actual=0
# Review 9634: Prediction=0, Actual=0
# Review 9635: Prediction=1, Actual=0
# Review 9636: Prediction=1, Actual=1
# Review 9637: Prediction=1, Actual=1
# Review 9638: Prediction=1, Actual=1
# Review 9639: Prediction=0, Actual=1
# Review 9640: Prediction=0, Actual=0
# Review 9641: Prediction=1, Actual=1
# Review 9642: Prediction=0, Actual=0
# Review 9643: Prediction=1, Actual=1
# Review 9644: Prediction=0, Actual=0
# Review 9645: Prediction=0, Actual=0
# Review 9646: Prediction=0, Actual=0
# Review 9647: Prediction=1, Actual=1
# Review 9648: Prediction=1, Actual=0
# Review 9649: Prediction=1, Actual=1
# Review 9650: Prediction=1, Actual=1
# Review 9651: Prediction=0, Actual=0
# Review 9652: Prediction=1, Actual=1
# Review 9653: Prediction=1, Actual=1
# Review 9654: Prediction=0, Actual=0
# Review 9655: Prediction=1, Actual=1
# Review 9656: Prediction=0, Actual=1
# Review 9657: Prediction=0, Actual=0
# Review 9658: Prediction=1, Actual=1
# Review 9659: Prediction=1, Actual=1
# Review 9660: Prediction=1, Actual=1
# Review 9661: Prediction=0, Actual=0
# Review 9662: Prediction=0, Actual=0
# Review 9663: Prediction=1, Actual=1
# Review 9664: Prediction=1, Actual=1
# Review 9665: Prediction=0, Actual=0
# Review 9666: Prediction=0, Actual=0
# Review 9667: Prediction=0, Actual=0
# Review 9668: Prediction=1, Actual=1
# Review 9669: Prediction=1, Actual=1
# Review 9670: Prediction=1, Actual=1
# Review 9671: Prediction=1, Actual=1
# Review 9672: Prediction=0, Actual=1
# Review 9673: Prediction=0, Actual=0
# Review 9674: Prediction=1, Actual=1
# Review 9675: Prediction=1, Actual=1
# Review 9676: Prediction=0, Actual=0
# Review 9677: Prediction=1, Actual=1
# Review 9678: Prediction=0, Actual=0
# Review 9679: Prediction=0, Actual=0
# Review 9680: Prediction=1, Actual=1
# Review 9681: Prediction=0, Actual=1
# Review 9682: Prediction=1, Actual=0
# Review 9683: Prediction=1, Actual=0
# Review 9684: Prediction=1, Actual=0
# Review 9685: Prediction=0, Actual=0
# Review 9686: Prediction=1, Actual=1
# Review 9687: Prediction=0, Actual=0
# Review 9688: Prediction=0, Actual=0
# Review 9689: Prediction=0, Actual=0
# Review 9690: Prediction=0, Actual=0
# Review 9691: Prediction=1, Actual=1
# Review 9692: Prediction=1, Actual=1
# Review 9693: Prediction=1, Actual=1
# Review 9694: Prediction=0, Actual=0
# Review 9695: Prediction=1, Actual=1
# Review 9696: Prediction=0, Actual=1
# Review 9697: Prediction=0, Actual=0
# Review 9698: Prediction=0, Actual=0
# Review 9699: Prediction=0, Actual=1
# Review 9700: Prediction=0, Actual=0
# Review 9701: Prediction=1, Actual=1
# Review 9702: Prediction=0, Actual=0
# Review 9703: Prediction=1, Actual=1
# Review 9704: Prediction=0, Actual=0
# Review 9705: Prediction=0, Actual=0
# Review 9706: Prediction=1, Actual=1
# Review 9707: Prediction=1, Actual=1
# Review 9708: Prediction=0, Actual=0
# Review 9709: Prediction=0, Actual=0
# Review 9710: Prediction=0, Actual=0
# Review 9711: Prediction=1, Actual=1
# Review 9712: Prediction=0, Actual=0
# Review 9713: Prediction=1, Actual=1
# Review 9714: Prediction=0, Actual=0
# Review 9715: Prediction=1, Actual=1
# Review 9716: Prediction=0, Actual=0
# Review 9717: Prediction=1, Actual=1
# Review 9718: Prediction=0, Actual=0
# Review 9719: Prediction=1, Actual=1
# Review 9720: Prediction=0, Actual=0
# Review 9721: Prediction=1, Actual=0
# Review 9722: Prediction=1, Actual=1
# Review 9723: Prediction=1, Actual=0
# Review 9724: Prediction=1, Actual=1
# Review 9725: Prediction=1, Actual=1
# Review 9726: Prediction=0, Actual=0
# Review 9727: Prediction=0, Actual=0
# Review 9728: Prediction=0, Actual=0
# Review 9729: Prediction=0, Actual=0
# Review 9730: Prediction=1, Actual=1
# Review 9731: Prediction=1, Actual=1
# Review 9732: Prediction=1, Actual=0
# Review 9733: Prediction=1, Actual=1
# Review 9734: Prediction=0, Actual=0
# Review 9735: Prediction=1, Actual=1
# Review 9736: Prediction=0, Actual=0
# Review 9737: Prediction=0, Actual=0
# Review 9738: Prediction=0, Actual=0
# Review 9739: Prediction=0, Actual=0
# Review 9740: Prediction=0, Actual=1
# Review 9741: Prediction=1, Actual=1
# Review 9742: Prediction=1, Actual=1
# Review 9743: Prediction=1, Actual=1
# Review 9744: Prediction=0, Actual=0
# Review 9745: Prediction=0, Actual=0
# Review 9746: Prediction=1, Actual=1
# Review 9747: Prediction=1, Actual=1
# Review 9748: Prediction=1, Actual=1
# Review 9749: Prediction=1, Actual=1
# Review 9750: Prediction=0, Actual=0
# Review 9751: Prediction=0, Actual=0
# Review 9752: Prediction=0, Actual=0
# Review 9753: Prediction=1, Actual=0
# Review 9754: Prediction=1, Actual=1
# Review 9755: Prediction=1, Actual=1
# Review 9756: Prediction=0, Actual=0
# Review 9757: Prediction=0, Actual=0
# Review 9758: Prediction=0, Actual=0
# Review 9759: Prediction=1, Actual=1
# Review 9760: Prediction=1, Actual=1
# Review 9761: Prediction=0, Actual=0
# Review 9762: Prediction=0, Actual=0
# Review 9763: Prediction=0, Actual=0
# Review 9764: Prediction=0, Actual=0
# Review 9765: Prediction=0, Actual=0
# Review 9766: Prediction=1, Actual=1
# Review 9767: Prediction=1, Actual=1
# Review 9768: Prediction=1, Actual=1
# Review 9769: Prediction=1, Actual=0
# Review 9770: Prediction=0, Actual=1
# Review 9771: Prediction=1, Actual=1
# Review 9772: Prediction=0, Actual=0
# Review 9773: Prediction=0, Actual=0
# Review 9774: Prediction=0, Actual=0
# Review 9775: Prediction=1, Actual=1
# Review 9776: Prediction=0, Actual=0
# Review 9777: Prediction=1, Actual=1
# Review 9778: Prediction=0, Actual=0
# Review 9779: Prediction=0, Actual=0
# Review 9780: Prediction=0, Actual=0
# Review 9781: Prediction=1, Actual=1
# Review 9782: Prediction=1, Actual=1
# Review 9783: Prediction=1, Actual=1
# Review 9784: Prediction=0, Actual=0
# Review 9785: Prediction=1, Actual=1
# Review 9786: Prediction=1, Actual=1
# Review 9787: Prediction=1, Actual=1
# Review 9788: Prediction=0, Actual=0
# Review 9789: Prediction=0, Actual=0
# Review 9790: Prediction=1, Actual=1
# Review 9791: Prediction=1, Actual=1
# Review 9792: Prediction=0, Actual=1
# Review 9793: Prediction=1, Actual=0
# Review 9794: Prediction=0, Actual=0
# Review 9795: Prediction=1, Actual=1
# Review 9796: Prediction=1, Actual=1
# Review 9797: Prediction=0, Actual=0
# Review 9798: Prediction=1, Actual=1
# Review 9799: Prediction=1, Actual=1
# Review 9800: Prediction=1, Actual=0
# Review 9801: Prediction=1, Actual=0
# Review 9802: Prediction=0, Actual=0
# Review 9803: Prediction=1, Actual=1
# Review 9804: Prediction=1, Actual=1
# Review 9805: Prediction=0, Actual=0
# Review 9806: Prediction=1, Actual=1
# Review 9807: Prediction=1, Actual=1
# Review 9808: Prediction=1, Actual=1
# Review 9809: Prediction=1, Actual=1
# Review 9810: Prediction=0, Actual=0
# Review 9811: Prediction=1, Actual=1
# Review 9812: Prediction=1, Actual=1
# Review 9813: Prediction=1, Actual=1
# Review 9814: Prediction=0, Actual=0
# Review 9815: Prediction=1, Actual=0
# Review 9816: Prediction=1, Actual=1
# Review 9817: Prediction=0, Actual=0
# Review 9818: Prediction=0, Actual=0
# Review 9819: Prediction=1, Actual=1
# Review 9820: Prediction=0, Actual=0
# Review 9821: Prediction=1, Actual=0
# Review 9822: Prediction=0, Actual=0
# Review 9823: Prediction=1, Actual=1
# Review 9824: Prediction=1, Actual=1
# Review 9825: Prediction=1, Actual=1
# Review 9826: Prediction=1, Actual=1
# Review 9827: Prediction=1, Actual=1
# Review 9828: Prediction=0, Actual=0
# Review 9829: Prediction=0, Actual=0
# Review 9830: Prediction=1, Actual=1
# Review 9831: Prediction=0, Actual=0
# Review 9832: Prediction=1, Actual=1
# Review 9833: Prediction=1, Actual=1
# Review 9834: Prediction=1, Actual=1
# Review 9835: Prediction=0, Actual=0
# Review 9836: Prediction=1, Actual=1
# Review 9837: Prediction=0, Actual=0
# Review 9838: Prediction=0, Actual=0
# Review 9839: Prediction=1, Actual=1
# Review 9840: Prediction=1, Actual=1
# Review 9841: Prediction=0, Actual=0
# Review 9842: Prediction=1, Actual=1
# Review 9843: Prediction=1, Actual=1
# Review 9844: Prediction=0, Actual=0
# Review 9845: Prediction=1, Actual=0
# Review 9846: Prediction=1, Actual=1
# Review 9847: Prediction=0, Actual=0
# Review 9848: Prediction=1, Actual=1
# Review 9849: Prediction=0, Actual=0
# Review 9850: Prediction=0, Actual=0
# Review 9851: Prediction=0, Actual=0
# Review 9852: Prediction=1, Actual=1
# Review 9853: Prediction=1, Actual=0
# Review 9854: Prediction=0, Actual=1
# Review 9855: Prediction=1, Actual=1
# Review 9856: Prediction=1, Actual=1
# Review 9857: Prediction=0, Actual=0
# Review 9858: Prediction=0, Actual=0
# Review 9859: Prediction=0, Actual=0
# Review 9860: Prediction=0, Actual=0
# Review 9861: Prediction=1, Actual=1
# Review 9862: Prediction=0, Actual=0
# Review 9863: Prediction=1, Actual=1
# Review 9864: Prediction=1, Actual=1
# Review 9865: Prediction=1, Actual=0
# Review 9866: Prediction=1, Actual=0
# Review 9867: Prediction=0, Actual=0
# Review 9868: Prediction=1, Actual=1
# Review 9869: Prediction=1, Actual=1
# Review 9870: Prediction=0, Actual=0
# Review 9871: Prediction=0, Actual=0
# Review 9872: Prediction=1, Actual=1
# Review 9873: Prediction=0, Actual=0
# Review 9874: Prediction=1, Actual=1
# Review 9875: Prediction=0, Actual=0
# Review 9876: Prediction=1, Actual=1
# Review 9877: Prediction=0, Actual=0
# Review 9878: Prediction=0, Actual=0
# Review 9879: Prediction=0, Actual=0
# Review 9880: Prediction=0, Actual=0
# Review 9881: Prediction=0, Actual=0
# Review 9882: Prediction=0, Actual=1
# Review 9883: Prediction=1, Actual=1
# Review 9884: Prediction=0, Actual=0
# Review 9885: Prediction=1, Actual=1
# Review 9886: Prediction=0, Actual=0
# Review 9887: Prediction=0, Actual=0
# Review 9888: Prediction=1, Actual=1
# Review 9889: Prediction=0, Actual=0
# Review 9890: Prediction=1, Actual=1
# Review 9891: Prediction=1, Actual=1
# Review 9892: Prediction=1, Actual=1
# Review 9893: Prediction=1, Actual=1
# Review 9894: Prediction=1, Actual=1
# Review 9895: Prediction=0, Actual=0
# Review 9896: Prediction=0, Actual=0
# Review 9897: Prediction=1, Actual=1
# Review 9898: Prediction=1, Actual=1
# Review 9899: Prediction=1, Actual=1
# Review 9900: Prediction=0, Actual=0
# Review 9901: Prediction=0, Actual=0
# Review 9902: Prediction=1, Actual=1
# Review 9903: Prediction=0, Actual=0
# Review 9904: Prediction=0, Actual=0
# Review 9905: Prediction=1, Actual=1
# Review 9906: Prediction=1, Actual=1
# Review 9907: Prediction=0, Actual=0
# Review 9908: Prediction=1, Actual=0
# Review 9909: Prediction=1, Actual=1
# Review 9910: Prediction=0, Actual=0
# Review 9911: Prediction=1, Actual=1
# Review 9912: Prediction=0, Actual=0
# Review 9913: Prediction=1, Actual=1
# Review 9914: Prediction=1, Actual=1
# Review 9915: Prediction=0, Actual=0
# Review 9916: Prediction=1, Actual=1
# Review 9917: Prediction=1, Actual=1
# Review 9918: Prediction=1, Actual=1
# Review 9919: Prediction=1, Actual=1
# Review 9920: Prediction=1, Actual=0
# Review 9921: Prediction=0, Actual=0
# Review 9922: Prediction=0, Actual=0
# Review 9923: Prediction=1, Actual=1
# Review 9924: Prediction=1, Actual=0
# Review 9925: Prediction=1, Actual=1
# Review 9926: Prediction=0, Actual=0
# Review 9927: Prediction=0, Actual=0
# Review 9928: Prediction=1, Actual=1
# Review 9929: Prediction=1, Actual=1
# Review 9930: Prediction=0, Actual=0
# Review 9931: Prediction=1, Actual=1
# Review 9932: Prediction=1, Actual=1
# Review 9933: Prediction=1, Actual=1
# Review 9934: Prediction=1, Actual=1
# Review 9935: Prediction=1, Actual=1
# Review 9936: Prediction=1, Actual=1
# Review 9937: Prediction=0, Actual=0
# Review 9938: Prediction=0, Actual=0
# Review 9939: Prediction=1, Actual=1
# Review 9940: Prediction=1, Actual=1
# Review 9941: Prediction=0, Actual=0
# Review 9942: Prediction=0, Actual=0
# Review 9943: Prediction=0, Actual=0
# Review 9944: Prediction=0, Actual=0
# Review 9945: Prediction=0, Actual=0
# Review 9946: Prediction=0, Actual=1
# Review 9947: Prediction=0, Actual=0
# Review 9948: Prediction=1, Actual=1
# Review 9949: Prediction=1, Actual=1
# Review 9950: Prediction=0, Actual=0
# Review 9951: Prediction=1, Actual=1
# Review 9952: Prediction=0, Actual=0
# Review 9953: Prediction=0, Actual=0
# Review 9954: Prediction=0, Actual=0
# Review 9955: Prediction=0, Actual=0
# Review 9956: Prediction=1, Actual=1
# Review 9957: Prediction=0, Actual=1
# Review 9958: Prediction=1, Actual=1
# Review 9959: Prediction=1, Actual=0
# Review 9960: Prediction=1, Actual=1
# Review 9961: Prediction=0, Actual=0
# Review 9962: Prediction=0, Actual=0
# Review 9963: Prediction=1, Actual=0
# Review 9964: Prediction=0, Actual=0
# Review 9965: Prediction=1, Actual=1
# Review 9966: Prediction=1, Actual=1
# Review 9967: Prediction=1, Actual=1
# Review 9968: Prediction=1, Actual=1
# Review 9969: Prediction=1, Actual=1
# Review 9970: Prediction=1, Actual=1
# Review 9971: Prediction=1, Actual=1
# Review 9972: Prediction=0, Actual=0
# Review 9973: Prediction=1, Actual=1
# Review 9974: Prediction=1, Actual=1
# Review 9975: Prediction=1, Actual=1
# Review 9976: Prediction=1, Actual=1
# Review 9977: Prediction=1, Actual=1
# Review 9978: Prediction=1, Actual=1
# Review 9979: Prediction=1, Actual=1
# Review 9980: Prediction=1, Actual=1
# Review 9981: Prediction=1, Actual=1
# Review 9982: Prediction=1, Actual=1
# Review 9983: Prediction=1, Actual=1
# Review 9984: Prediction=0, Actual=0
# Review 9985: Prediction=0, Actual=0
# Review 9986: Prediction=0, Actual=0
# Review 9987: Prediction=1, Actual=1
# Review 9988: Prediction=1, Actual=1
# Review 9989: Prediction=0, Actual=1
# Review 9990: Prediction=0, Actual=0
# Review 9991: Prediction=1, Actual=0
# Review 9992: Prediction=0, Actual=0
# Review 9993: Prediction=0, Actual=1
# Review 9994: Prediction=1, Actual=0
# Review 9995: Prediction=1, Actual=1
# Review 9996: Prediction=0, Actual=0
# Review 9997: Prediction=1, Actual=1
# Review 9998: Prediction=1, Actual=1
# Review 9999: Prediction=0, Actual=0
# Review 10000: Prediction=1, Actual=1

# %%
# Save the trained SVM model and TF-IDF vectorizer
joblib.dump(svm_model, 'svm_model.pkl')
joblib.dump(tfidf, 'tfidf_vectorizer.pkl')
# Out:
# ['tfidf_vectorizer.pkl']

# %%
# Aspect-Based Sentiment Analysis
# Load Spacy model
nlp = spacy.load('en_core_web_sm')

# %%
from transformers import pipeline

# Specify model and tokenizer explicitly
model_name = "distilbert-base-uncased-finetuned-sst-2-english"

sentiment_pipeline = pipeline('sentiment-analysis')

# Example usage
texts = ["I love this movie!", "I hate this movie."]
results = sentiment_pipeline(texts)

for text, result in zip(texts, results):
    print(f"Text: {text}")
    print(f"Label: {result['label']}, Score: {result['score']}")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Text: I love this movie!
# Label: POSITIVE, Score: 0.9998775720596313
# Text: I hate this movie.
# Label: NEGATIVE, Score: 0.9996869564056396

# %%
# Define aspects
aspects = ['acting', 'direction', 'storyline', 'special effects']

# Function to identify aspects in a review
def identify_aspects(review):
    doc = nlp(review)
    review_aspects = []
    for token in doc:
        if token.lemma_ in aspects:
            review_aspects.append(token.lemma_)
    return review_aspects

data['aspects'] = data['review'].apply(identify_aspects)

# Load sentiment analysis pipeline
sentiment_pipeline = pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# D:\Programs\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:982: UserWarning: Not enough free disk space to download the file. The expected file size is: 267.83 MB. The target location C:\Users\Chidimez\.cache\huggingface\hub\models--distilbert--distilbert-base-uncased-finetuned-sst-2-english\blobs only has 257.13 MB free disk space.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
# Function to get sentiment for each aspect
def aspect_sentiment(review, aspects):
    sentiments = {}
    max_length = 512  # Maximum token length for the model

    for aspect in aspects:
        if aspect in review:
            # Find sentences containing the aspect
            aspect_sentence = [sent for sent in review.split('.') if aspect in sent]
            if aspect_sentence:
                # Join sentences and truncate to max_length
                joined_sentence = ' '.join(aspect_sentence)
                if len(joined_sentence) > max_length:
                    joined_sentence = joined_sentence[:max_length]

                # Get sentiment
                sentiment_result = sentiment_pipeline(joined_sentence)
                sentiments[aspect] = sentiment_result[0]['label']
    return sentiments


# Apply sentiment analysis for each review's aspects
data['aspect_sentiments'] = data.apply(lambda x: aspect_sentiment(x['review'], x['aspects']), axis=1)

# Display some results
for i in range(10):
    print(f"Review {i+1}:")
    print(data['review'].iloc[i])
    print("Aspects Identified:", data['aspects'].iloc[i])
    print("Aspect Sentiments:", data['aspect_sentiments'].iloc[i])
    print("\n")
# Out:
# Review 1:
# one of the other reviewers has mentioned that after watching just  oz episode youll be hooked they are right as this is exactly what happened with me  the first thing that struck me about oz was its brutality and unflinching scenes of violence which set in right from the word go trust me this is not a show for the faint hearted or timid this show pulls no punches with regards to drugs sex or violence its is hardcore in the classic use of the word  it is called oz as that is the nickname given to the oswald maximum security state penitentary it focuses mainly on emerald city an experimental section of the prison where all the cells have glass fronts and face inwards so privacy is not high on the agenda em city is home to manyaryans muslims gangstas latinos christians italians irish and moreso scuffles death stares dodgy dealings and shady agreements are never far away  i would say the main appeal of the show is due to the fact that it goes where other shows wouldnt dare forget pretty pictures painted for mainstream audiences forget charm forget romanceoz doesnt mess around the first episode i ever saw struck me as so nasty it was surreal i couldnt say i was ready for it but as i watched more i developed a taste for oz and got accustomed to the high levels of graphic violence not just violence but injustice crooked guards wholl be sold out for a nickel inmates wholl kill on order and get away with it well mannered middle class inmates being turned into prison bitches due to their lack of street skills or prison experience watching oz you may become comfortable with what is uncomfortable viewingthats if you can get in touch with your darker side
# Aspects Identified: []
# Aspect Sentiments: {}
#
#
# Review 2:
# a wonderful little production   the filming technique is very unassuming very oldtimebbc fashion and gives a comforting and sometimes discomforting sense of realism to the entire piece   the actors are extremely well chosen michael sheen not only has got all the polari but he has all the voices down pat too you can truly see the seamless editing guided by the references to williams diary entries not only is it well worth the watching but it is a terrificly written and performed piece a masterful production about one of the great masters of comedy and his life   the realism really comes home with the little things the fantasy of the guard which rather than use the traditional dream techniques remains solid then disappears it plays on our knowledge and our senses particularly with the scenes concerning orton and halliwell and the sets particularly of their flat with halliwells murals decorating every surface are terribly well done
# Aspects Identified: []
# Aspect Sentiments: {}
#
#
# Review 3:
# i thought this was a wonderful way to spend time on a too hot summer weekend sitting in the air conditioned theater and watching a lighthearted comedy the plot is simplistic but the dialogue is witty and the characters are likable even the well bread suspected serial killer while some may be disappointed when they realize this is not match point  risk addiction i thought it was proof that woody allen is still fully in control of the style many of us have grown to love  this was the most id laughed at one of woodys comedies in years dare i say a decade while ive never been impressed with scarlet johanson in this she managed to tone down her sexy image and jumped right into a average but spirited young woman  this may not be the crown jewel of his career but it was wittier than devil wears prada and more interesting than superman a great comedy to go see with friends
# Aspects Identified: []
# Aspect Sentiments: {}
#
#
# Review 4:
# basically theres a family where a little boy jake thinks theres a zombie in his closet  his parents are fighting all the time  this movie is slower than a soap opera and suddenly jake decides to become rambo and kill the zombie  ok first of all when youre going to make a film you must decide if its a thriller or a drama as a drama the movie is watchable parents are divorcing  arguing like in real life and then we have jake with his closet which totally ruins all the film i expected to see a boogeyman similar movie and instead i watched a drama with some meaningless thriller spots   out of  just for the well playing parents  descent dialogs as for the shots with jake just ignore them
# Aspects Identified: []
# Aspect Sentiments: {}
#
#
# Review 5:
# petter matteis love in the time of money is a visually stunning film to watch mr mattei offers us a vivid portrait about human relations this is a movie that seems to be telling us what money power and success do to people in the different situations we encounter   this being a variation on the arthur schnitzlers play about the same theme the director transfers the action to the present time new york where all these different characters meet and connect each one is connected in one way or another to the next person but no one seems to know the previous point of contact stylishly the film has a sophisticated luxurious look we are taken to see how these people live and the world they live in their own habitat  the only thing one gets out of all these souls in the picture is the different stages of loneliness each one inhabits a big city is not exactly the best place in which human relations find sincere fulfillment as one discerns is the case with most of the people we encounter  the acting is good under mr matteis direction steve buscemi rosario dawson carol kane michael imperioli adrian grenier and the rest of the talented cast make these characters come alive  we wish mr mattei good luck and await anxiously for his next work
# Aspects Identified: ['acting', 'direction']
# Aspect Sentiments: {'acting': 'POSITIVE', 'direction': 'POSITIVE'}
#
#
# Review 6:
# probably my alltime favorite movie a story of selflessness sacrifice and dedication to a noble cause but its not preachy or boring it just never gets old despite my having seen it some  or more times in the last  years paul lukas performance brings tears to my eyes and bette davis in one of her very few truly sympathetic roles is a delight the kids are as grandma says more like dressedup midgets than children but that only makes them more fun to watch and the mothers slow awakening to whats happening in the world and under her own roof is believable and startling if i had a dozen thumbs theyd all be up for this movie
# Aspects Identified: []
# Aspect Sentiments: {}
#
#
# Review 7:
# i sure would like to see a resurrection of a up dated seahunt series with the tech they have today it would bring back the kid excitement in mei grew up on black and white tv and seahunt with gunsmoke were my heros every weekyou have my vote for a comeback of a new sea huntwe need a change of pace in tv and this would work for a world of under water adventureoh by the way thank you for an outlet like this to view many viewpoints about tv and the many moviesso any ole way i believe ive got what i wanna saywould be nice to read some more plus points about sea huntif my rhymes would be  lines would you let me submitor leave me out to be in doubt and have me to quitif this is so then i must go so lets do it
# Aspects Identified: []
# Aspect Sentiments: {}
#
#
# Review 8:
# this show was an amazing fresh  innovative idea in the s when it first aired the first  or  years were brilliant but things dropped off after that by  the show was not really funny anymore and its continued its decline further to the complete waste of time it is today  its truly disgraceful how far this show has fallen the writing is painfully bad the performances are almost as bad  if not for the mildly entertaining respite of the guesthosts this show probably wouldnt still be on the air i find it so hard to believe that the same creator that handselected the original cast also chose the band of hacks that followed how can one recognize such brilliance and then see fit to replace it with such mediocrity i felt i must give  stars out of respect for the original cast that made this show such a huge success as it is now the show is just awful i cant believe its still on the air
# Aspects Identified: []
# Aspect Sentiments: {}
#
#
# Review 9:
# encouraged by the positive comments about this film on here i was looking forward to watching this film bad mistake ive seen  films and this is truly one of the worst of them  its awful in almost every way editing pacing storyline acting soundtrack the films only song  a lame country tune  is played no less than four times the film looks cheap and nasty and is boring in the extreme rarely have i been so happy to see the end credits of a film   the only thing that prevents me giving this a score is harvey keitel  while this is far from his best performance he at least seems to be making a bit of an effort one for keitel obsessives only
# Aspects Identified: ['storyline', 'acting']
# Aspect Sentiments: {'storyline': 'NEGATIVE', 'acting': 'NEGATIVE'}
#
#
# Review 10:
# if you like original gut wrenching laughter you will like this movie if you are young or old then you will love this movie hell even my mom liked it  great camp
# Aspects Identified: []
# Aspect Sentiments: {}

# %%
# Load the trained SVM model and TF-IDF vectorizer for real-time predictions
svm_model = joblib.load('svm_model.pkl')
tfidf = joblib.load('tfidf_vectorizer.pkl')

# Define a function for real-time prediction
def preprocess_and_predict(review):
    cleaned_review = clean_text(review)
    transformed_review = tfidf.transform([cleaned_review])
    sentiment = svm_model.predict(transformed_review)
    sentiment_label = 'positive' if sentiment == 1 else 'negative'
    return sentiment_label

# %%
# Example usage for a new review
new_review = "The acting was fantastic but the storyline was a bit dull."
predicted_sentiment = preprocess_and_predict(new_review)
print(f"Predicted Sentiment: {predicted_sentiment}")

# Simulate receiving new reviews and predicting their sentiments
new_reviews = [
    "The special effects were stunning and the plot was engaging!",
    "I found the movie to be quite boring and predictable.",
    "Great performances by the cast but the direction was weak.",
    "An absolute masterpiece! Thoroughly enjoyed every moment."
]

for review in new_reviews:
    predicted_sentiment = preprocess_and_predict(review)
    print(f"Review: {review}")
    print(f"Predicted Sentiment: {predicted_sentiment}\n")
